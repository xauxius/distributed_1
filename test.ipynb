# %%
import time

st = time.time()
time.sleep(1)
print(time.time() - st)
# Out:
# 1.0005743503570557

# %%
# n = "bam"
# print(n + 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 n = "bam"
# ----> 2 print(n + 1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
d = {"bim": 5, "bam": 3}
print(d.get("biim"))
# Out:
# None
